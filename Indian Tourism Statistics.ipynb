# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\user\Downloads\India-Tourism-Statistics-2021-Table-5.2.3.csv')

# %%
df.tail()
# Out:
#           Circle                              Name of the Monument   \
# 173    Amaravati                                    Nagarjuna Kunda
# 174    Amaravati                               Chandragiri Monument
# 175    Amaravati  Buddhist Remains on hill top at Guntupalli, W....
# 176        Total                                              Total
# 177  Grand Total                                        Grand Total
#
#      Domestic-2019-20  Foreign-2019-20  Domestic-2020-21  Foreign-2020-21  \
# 173             19762               35                 0                0
# 174            103489              109             51113               38
# 175             22353               85             10219               10
# 176            262949             1008            116120              137
# 177          43607075          2756561          13153076           415859
#
#      % Growth 2021-21/2019-20-Domestic  % Growth 2021-21/2019-20-Foreign
# 173                                NaN                               NaN
# 174                             -50.61                            -65.14
# 175                             -54.28                            -88.24
# 176                             -55.84                            -86.41
# 177                             -69.84                            -84.91

# %%
df.shape
# Out:
# (178, 8)

# %%
missing_data = df.isnull()
missing_data.head(5)
# Out:
#    Circle  Name of the Monument   Domestic-2019-20  Foreign-2019-20  \
# 0   False                  False             False            False
# 1   False                  False             False            False
# 2   False                  False             False            False
# 3   False                  False             False            False
# 4   False                  False             False            False
#
#    Domestic-2020-21  Foreign-2020-21  % Growth 2021-21/2019-20-Domestic  \
# 0             False            False                              False
# 1             False            False                              False
# 2             False            False                              False
# 3             False            False                              False
# 4             False            False                              False
#
#    % Growth 2021-21/2019-20-Foreign
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Circle
# False    178
# Name: Circle, dtype: int64
#
# Name of the Monument
# False    178
# Name: Name of the Monument , dtype: int64
#
# Domestic-2019-20
# False    178
# Name: Domestic-2019-20, dtype: int64
#
# Foreign-2019-20
# False    178
# Name: Foreign-2019-20, dtype: int64
#
# Domestic-2020-21
# False    178
# Name: Domestic-2020-21, dtype: int64
#
# Foreign-2020-21
# False    178
# Name: Foreign-2020-21, dtype: int64
#
# % Growth 2021-21/2019-20-Domestic
# False    177
# True       1
# Name: % Growth 2021-21/2019-20-Domestic, dtype: int64
#
# % Growth 2021-21/2019-20-Foreign
# False    176
# True       2
# Name: % Growth 2021-21/2019-20-Foreign, dtype: int64

# %%
# Handle missing values by filling them with the mean value of each column
df.fillna(df.mean(), inplace=True)

# %%
mean=df["% Growth 2021-21/2019-20-Domestic"].mean()

# %%
df["% Growth 2021-21/2019-20-Domestic"].replace(np.nan, mean)
# Out:
# 0     -71.560000
# 1     -77.180000
# 2     -76.270000
# 3     -56.600000
# 4     -56.630000
#          ...
# 173   -28.225367
# 174   -50.610000
# 175   -54.280000
# 176   -55.840000
# 177   -69.840000
# Name: % Growth 2021-21/2019-20-Domestic, Length: 178, dtype: float64

# %%
mean1=df["% Growth 2021-21/2019-20-Foreign"].mean()

# %%
df["% Growth 2021-21/2019-20-Foreign"].replace(np.nan, mean1)
# Out:
# 0      -98.600000
# 1      -99.270000
# 2      -99.690000
# 3      -98.360000
# 4      -92.510000
#           ...
# 173    937.419148
# 174    -65.140000
# 175    -88.240000
# 176    -86.410000
# 177    -84.910000
# Name: % Growth 2021-21/2019-20-Foreign, Length: 178, dtype: float64

# %%
missing_data = df.isnull()
missing_data.head(5)
# Out:
#    Circle  Name of the Monument   Domestic-2019-20  Foreign-2019-20  \
# 0   False                  False             False            False
# 1   False                  False             False            False
# 2   False                  False             False            False
# 3   False                  False             False            False
# 4   False                  False             False            False
#
#    Domestic-2020-21  Foreign-2020-21  % Growth 2021-21/2019-20-Domestic  \
# 0             False            False                              False
# 1             False            False                              False
# 2             False            False                              False
# 3             False            False                              False
# 4             False            False                              False
#
#    % Growth 2021-21/2019-20-Foreign
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Circle
# False    178
# Name: Circle, dtype: int64
#
# Name of the Monument
# False    178
# Name: Name of the Monument , dtype: int64
#
# Domestic-2019-20
# False    178
# Name: Domestic-2019-20, dtype: int64
#
# Foreign-2019-20
# False    178
# Name: Foreign-2019-20, dtype: int64
#
# Domestic-2020-21
# False    178
# Name: Domestic-2020-21, dtype: int64
#
# Foreign-2020-21
# False    178
# Name: Foreign-2020-21, dtype: int64
#
# % Growth 2021-21/2019-20-Domestic
# False    178
# Name: % Growth 2021-21/2019-20-Domestic, dtype: int64
#
# % Growth 2021-21/2019-20-Foreign
# False    178
# Name: % Growth 2021-21/2019-20-Foreign, dtype: int64

# %%
# Reformat data types
df["Circle"] = df["Circle"].astype(object)

# %%
df.dtypes
# Out:
# Circle                                object
# Name of the Monument                  object
# Domestic-2019-20                       int64
# Foreign-2019-20                        int64
# Domestic-2020-21                       int64
# Foreign-2020-21                        int64
# % Growth 2021-21/2019-20-Domestic    float64
# % Growth 2021-21/2019-20-Foreign     float64
# dtype: object

# %%
df.describe(include="all")
# Out:
#        Circle Name of the Monument   Domestic-2019-20  Foreign-2019-20  \
# count     178                   178      1.780000e+02     1.780000e+02
# unique     35                   146               NaN              NaN
# top     Total                 Total               NaN              NaN
# freq       33                    33               NaN              NaN
# mean      NaN                   NaN      7.349507e+05     4.645889e+04
# std       NaN                   NaN      3.375224e+06     2.412842e+05
# min       NaN                   NaN      5.300000e+02     0.000000e+00
# 25%       NaN                   NaN      4.586950e+04     1.697500e+02
# 50%       NaN                   NaN      1.765070e+05     1.747000e+03
# 75%       NaN                   NaN      4.641905e+05     1.242850e+04
# max       NaN                   NaN      4.360708e+07     2.756561e+06
#
#         Domestic-2020-21  Foreign-2020-21  % Growth 2021-21/2019-20-Domestic  \
# count       1.780000e+02       178.000000                         178.000000
# unique               NaN              NaN                                NaN
# top                  NaN              NaN                                NaN
# freq                 NaN              NaN                                NaN
# mean        2.216811e+05      7008.859551                         -28.225367
# std         1.009087e+06     40252.182392                         335.896728
# min         0.000000e+00         0.000000                         -99.990000
# 25%         1.427275e+04        14.500000                         -76.697500
# 50%         5.747650e+04       101.500000                         -63.775000
# 75%         1.524880e+05       340.000000                         -50.845000
# max         1.315308e+07    415859.000000                        4233.770000
#
#         % Growth 2021-21/2019-20-Foreign
# count                         178.000000
# unique                               NaN
# top                                  NaN
# freq                                 NaN
# mean                          937.419148
# std                          6820.699521
# min                          -100.000000
# 25%                           -98.987500
# 50%                           -96.925000
# 75%                           -80.522500
# max                         62078.430000

# %%
df=df.sample(n=100, random_state=42)

# %%
df.shape
# Out:
# (100, 8)

# %%
df.head()
# Out:
#       Circle Name of the Monument   Domestic-2019-20  Foreign-2019-20  \
# 19   Sarnath  Lord Cornwallis Tomb             18318               85
# 45    Bhopal   Hoshang Shah's Tomb            130094             2017
# 140      Goa     Upper Fort Aguada            837898             8104
# 30     Total                 Total           1044418            83629
# 67     Hampi          Bellary Fort             28723               56
#
#      Domestic-2020-21  Foreign-2020-21  % Growth 2021-21/2019-20-Domestic  \
# 19               5289                9                             -71.13
# 45              57769               39                             -55.59
# 140            379726              340                             -54.68
# 30             247969              560                             -76.26
# 67              11069                9                             -61.46
#
#      % Growth 2021-21/2019-20-Foreign
# 19                             -89.41
# 45                             -98.07
# 140                            -95.80
# 30                             -99.33
# 67                             -83.93

# %%
df.nunique()
# Out:
# Circle                               34
# Name of the Monument                 85
# Domestic-2019-20                     99
# Foreign-2019-20                      97
# Domestic-2020-21                     99
# Foreign-2020-21                      77
# % Growth 2021-21/2019-20-Domestic    98
# % Growth 2021-21/2019-20-Foreign     87
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.corr()
# Out:
#                                    Domestic-2019-20  Foreign-2019-20  \
# Domestic-2019-20                           1.000000         0.824733
# Foreign-2019-20                            0.824733         1.000000
# Domestic-2020-21                           0.953161         0.788883
# Foreign-2020-21                            0.100716         0.118321
# % Growth 2021-21/2019-20-Domestic         -0.071957        -0.034088
# % Growth 2021-21/2019-20-Foreign          -0.057802        -0.030264
#
#                                    Domestic-2020-21  Foreign-2020-21  \
# Domestic-2019-20                           0.953161         0.100716
# Foreign-2019-20                            0.788883         0.118321
# Domestic-2020-21                           1.000000         0.126236
# Foreign-2020-21                            0.126236         1.000000
# % Growth 2021-21/2019-20-Domestic         -0.062654        -0.023369
# % Growth 2021-21/2019-20-Foreign          -0.053111         0.381651
#
#                                    % Growth 2021-21/2019-20-Domestic  \
# Domestic-2019-20                                           -0.071957
# Foreign-2019-20                                            -0.034088
# Domestic-2020-21                                           -0.062654
# Foreign-2020-21                                            -0.023369
# % Growth 2021-21/2019-20-Domestic                           1.000000
# % Growth 2021-21/2019-20-Foreign                            0.072073
#
#                                    % Growth 2021-21/2019-20-Foreign
# Domestic-2019-20                                          -0.057802
# Foreign-2019-20                                           -0.030264
# Domestic-2020-21                                          -0.053111
# Foreign-2020-21                                            0.381651
# % Growth 2021-21/2019-20-Domestic                          0.072073
# % Growth 2021-21/2019-20-Foreign                           1.000000

# %%
# Heatmap
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
df['Circle'].unique()
# Out:
# array(['Sarnath', 'Bhopal', 'Goa', 'Total', 'Hampi', 'Jhansi',
#        'Chandigarh', 'Amaravati', 'Mumbai', 'Jodhpur', 'Tiruchirappalli',
#        'Rajkot', 'Dharwad', 'Srinagar', 'Shimla', 'Nagpur', 'Bhubaneswar',
#        'Jabalpur', 'Thrissur', 'Delhi', 'Chennai', 'Lucknow', 'Patna',
#        'Guwahati', 'Aurangabad', 'Vadodara', 'Hyderabad', 'Agra', 'Leh',
#        'Kolkata', 'Jaipur', 'Banglore', 'Raiganj', 'Raipur'], dtype=object)

# %%
##Use the method value_counts to count the number of each unique values, using the method .to_frame() to convert it to a dataframe.
df['Circle'].value_counts().to_frame()
# Out:
#                  Circle
# Total                16
# Delhi                 6
# Mumbai                6
# Tiruchirappalli       5
# Aurangabad            5
# Sarnath               4
# Bhopal                4
# Agra                  4
# Thrissur              4
# Amaravati             3
# Hyderabad             3
# Lucknow               3
# Vadodara              3
# Guwahati              3
# Chandigarh            2
# Patna                 2
# Jaipur                2
# Dharwad               2
# Jabalpur              2
# Hampi                 2
# Rajkot                2
# Chennai               2
# Jhansi                2
# Srinagar              2
# Bhubaneswar           2
# Shimla                1
# Banglore              1
# Nagpur                1
# Jodhpur               1
# Kolkata               1
# Raipur                1
# Leh                   1
# Raiganj               1
# Goa                   1

# %%
df['Circle'].value_counts()
# Out:
# Total              16
# Delhi               6
# Mumbai              6
# Tiruchirappalli     5
# Aurangabad          5
# Sarnath             4
# Bhopal              4
# Agra                4
# Thrissur            4
# Amaravati           3
# Hyderabad           3
# Lucknow             3
# Vadodara            3
# Guwahati            3
# Chandigarh          2
# Patna               2
# Jaipur              2
# Dharwad             2
# Jabalpur            2
# Hampi               2
# Rajkot              2
# Chennai             2
# Jhansi              2
# Srinagar            2
# Bhubaneswar         2
# Shimla              1
# Banglore            1
# Nagpur              1
# Jodhpur             1
# Kolkata             1
# Raipur              1
# Leh                 1
# Raiganj             1
# Goa                 1
# Name: Circle, dtype: int64

# %%
#Use the function boxplot in the seaborn library to determine whether houses with a waterfront view or without a waterfront view have more price outliers.
# %matplotlib inline 
width =14
height = 10
plt.figure(figsize=(width, height))
sns.boxplot(x=df['Domestic-2019-20'],y=df['Circle'])
plt.show()

# %%
grouped = df.groupby('Circle')

# %%
# Calculate the mean of each group
grouped_mean = grouped['Domestic-2019-20'].mean()

print(grouped_mean)
# Out:
# Circle
# Agra               1.247664e+06
# Amaravati          4.376300e+04
# Aurangabad         6.684700e+05
# Banglore           6.465600e+05
# Bhopal             1.458980e+05
# Bhubaneswar        1.778440e+05
# Chandigarh         6.560500e+04
# Chennai            6.837155e+05
# Delhi              5.861033e+05
# Dharwad            1.925350e+05
# Goa                8.378980e+05
# Guwahati           5.469500e+04
# Hampi              3.079805e+05
# Hyderabad          9.583473e+05
# Jabalpur           1.341745e+05
# Jaipur             1.288270e+05
# Jhansi             4.873050e+04
# Jodhpur            5.651330e+05
# Kolkata            6.050000e+02
# Leh                5.663900e+04
# Lucknow            7.642900e+04
# Mumbai             2.820180e+05
# Nagpur             1.596000e+03
# Patna              2.515395e+05
# Raiganj            6.741130e+05
# Raipur             6.375900e+04
# Rajkot             1.230650e+04
# Sarnath            1.413975e+05
# Shimla             9.130600e+04
# Srinagar           6.170500e+03
# Thrissur           2.611045e+05
# Tiruchirappalli    1.054818e+05
# Total              1.582237e+06
# Vadodara           2.015213e+05
# Name: Domestic-2019-20, dtype: float64

# %%
# Calculate the unique of each group
grouped_unique = grouped['Domestic-2019-20'].unique()

print(grouped_unique)
# Out:
# Circle
# Agra                                 [454376, 84051, 22517, 4429710]
# Amaravati                                      [103489, 8038, 19762]
# Aurangabad                [515935, 182032, 1111778, 273344, 1259261]
# Banglore                                                    [646560]
# Bhopal                                [130094, 13708, 47305, 392485]
# Bhubaneswar                                          [311115, 44573]
# Chandigarh                                            [91447, 39763]
# Chennai                                            [1260358, 107073]
# Delhi                   [145544, 1782, 530, 658318, 2048146, 662300]
# Dharwad                                              [372051, 13019]
# Goa                                                         [837898]
# Guwahati                                      [21062, 23111, 119912]
# Hampi                                                [28723, 587238]
# Hyderabad                                  [1630419, 92690, 1151933]
# Jabalpur                                             [23354, 244995]
# Jaipur                                               [190833, 66821]
# Jhansi                                                [15954, 81507]
# Jodhpur                                                     [565133]
# Kolkata                                                        [605]
# Leh                                                          [56639]
# Lucknow                                       [38342, 116348, 74597]
# Mumbai                [218338, 62238, 41490, 161651, 80319, 1128072]
# Nagpur                                                        [1596]
# Patna                                                [437506, 65573]
# Raiganj                                                     [674113]
# Raipur                                                       [63759]
# Rajkot                                                 [5858, 18755]
# Sarnath                                 [18318, 55144, 485309, 6819]
# Shimla                                                       [91306]
# Srinagar                                                [5731, 6610]
# Thrissur                            [234518, 334846, 300465, 174589]
# Tiruchirappalli                [159492, 30046, 19114, 294829, 23928]
# Total              [1044418, 837898, 45391, 7632914, 460103, 1803...
# Vadodara                                     [208028, 59402, 337134]
# Name: Domestic-2019-20, dtype: object

# %%
df['% Growth 2021-21/2019-20-Domestic'].unique()
# Out:
# array([-7.11300000e+01, -5.55900000e+01, -5.46800000e+01, -7.62600000e+01,
#        -6.14600000e+01, -6.42000000e+01, -8.78300000e+01, -5.06100000e+01,
#        -6.49900000e+01, -7.28800000e+01, -6.04800000e+01, -9.68300000e+01,
#        -9.99700000e+01, -1.49000000e+00, -8.18600000e+01, -9.96000000e+01,
#        -7.29900000e+01, -8.08000000e+01, -4.31500000e+01, -5.34300000e+01,
#        -5.37000000e+01,  1.48000000e+00, -7.68100000e+01,  1.00200000e+01,
#        -9.95000000e+01, -6.02400000e+01, -7.63000000e+01, -2.91500000e+01,
#        -7.19900000e+01, -7.26300000e+01, -6.90800000e+01, -3.58800000e+01,
#        -6.85400000e+01, -7.97700000e+01, -7.58300000e+01, -8.61300000e+01,
#        -7.95600000e+01, -5.79400000e+01, -9.92800000e+01, -8.63300000e+01,
#        -5.89400000e+01, -5.38100000e+01, -6.76700000e+01, -7.62700000e+01,
#        -8.07900000e+01,  6.84600000e+01, -9.63900000e+01, -2.93200000e+01,
#        -5.72100000e+01, -4.75400000e+01, -6.55600000e+01, -5.71200000e+01,
#        -1.40400000e+01, -8.57700000e+01,  1.19223000e+03, -9.22800000e+01,
#        -5.88100000e+01, -6.48500000e+01, -7.17300000e+01, -8.16700000e+01,
#        -8.62300000e+01, -6.77900000e+01, -5.08400000e+01, -7.78700000e+01,
#        -9.23400000e+01, -3.05900000e+01, -5.66300000e+01,  1.68400000e+01,
#        -8.26000000e+01, -3.87300000e+01, -4.63700000e+01, -6.35400000e+01,
#        -3.37300000e+01,  4.23377000e+03, -7.15600000e+01, -7.41700000e+01,
#        -6.29600000e+01, -5.65900000e+01, -7.05600000e+01, -8.70300000e+01,
#        -7.48400000e+01, -8.59300000e+01, -7.67600000e+01, -6.68100000e+01,
#        -7.10800000e+01, -6.96700000e+01, -9.96900000e+01, -1.97100000e+01,
#        -3.43200000e+01, -8.95900000e+01, -8.43400000e+01, -7.12600000e+01,
#        -2.38200000e+01, -2.82253672e+01, -2.98300000e+01, -6.21200000e+01,
#        -7.28900000e+01, -5.44700000e+01])

# %%
##Use the method value_counts to count the number of each unique values, using the method .to_frame() to convert it to a dataframe.

df['% Growth 2021-21/2019-20-Domestic'].value_counts().to_frame()
# Out:
#         % Growth 2021-21/2019-20-Domestic
# -54.68                                  2
# -71.13                                  2
# -76.76                                  1
# -76.26                                  1
# -64.99                                  1
# ...                                   ...
# -29.15                                  1
# -99.97                                  1
# -69.67                                  1
# -64.85                                  1
# -99.50                                  1
#
# [98 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Countplot
sns.countplot(y="Circle", data=df)
plt.show()

# %%
import matplotlib as plt
from matplotlib import pyplot

plt.pyplot.hist(df['Domestic-2019-20'],bins=10)
plt.pyplot.ylabel('Domestic-2019-20')
plt.pyplot.xlabel("count")
plt.pyplot.title("Domestic-2019-20_bins")
# Out:
# Text(0.5, 1.0, 'Domestic-2019-20_bins')

# %%
# Scatter plot
sns.scatterplot(y="Circle", x="Domestic-2019-20", data=df)
plt.show()

# %%
# Boxplot
sns.boxplot(y="Circle", x="Domestic-2019-20", data=df)
plt.show()
